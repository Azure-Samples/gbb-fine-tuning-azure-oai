# %% [markdown]
# # Case Study: Finetuning with Function Calling for Stock Prices
#
# In this case study, we will demonstrate the utility of function calling with fine-tuned models by addressing a real-world problem. Our goal is to build a chatbot that retrieves stock prices from an external API in response to user inquiries. Using the base model, we encountered two main challenges:
# 1. The model struggles to distinguish real companies from fake ones.
# 2. The function calling definitions were excessively long, significantly increasing the tokens per prompt.
#
# We will explore how fine-tuning, combined with function calling, can enhance the model's accuracy and performance. The steps include:
# - Building a training dataset.
# - Comparing the fine-tuned model to the base model.
# - Measuring the improvements from fine-tuning.
#
# Once we have created a fine-tuned model that meets our requirements, we will develop a cost comparison to evaluate the benefits.

# %% [markdown]
# ### 0. Function Calling:
#
# Function calling allows an LLM to create a call to an external API – it doesn’t execute it. To actually execute the request, you’ll need to extract the function name and arguments from the LLM response and proceed to call the function with those arguments. The function's output is in JSON format, which is then passed back to the LLM to generate an appropriate result message for the user.

# %% [markdown]
# ### 1. Finetuning a GPT-4o:
#
# Azure OpenAI uses LoRA to fine tune models efficiently. **LoRA (Low-Rank Adaptation)** finetuning of a Large Language Model is a technique used to adapt pre-trained language models to specific tasks efficiently and with fewer computational resources.
#
#  Instead of adjusting all the model parameters, LoRA introduces a small number of additional parameters (low-rank matrices) that modify the model's behavior. These new parameters are trained while keeping the original model's parameters mostly unchanged. This way, the model can learn the new task without the need for extensive computational resources or time.

# %% [markdown]
# ### 2. How much will this cost?
#
# For detailed pricing information, visit the [Azure OpenAI Service Pricing](https://azure.microsoft.com/en-us/pricing/details/cognitive-services/openai-service/).
#
# To estimate the cost of our fine-tuning job, we can use the following formula:
#
# `(Training cost per 1K input tokens / 1K) * number of tokens in input file * number of epochs trained`
#
# **Epoch:** A complete iteration through a dataset during the training process.
#
# 1. **If the number of epochs is too low:** Your model might be underfitted, meaning it could perform poorly because it hasn't learned enough from the training data. It may not have had enough iterations to effectively learn and adjust its parameters (e.g., weights and biases).
#
# 2. **If the number of epochs is too high:** There's a risk of overfitting, where the model becomes too specialized in the training data and performs poorly on unseen data (examples that weren’t in your training dataset).
#
# The number of epochs is a parameter of the fine-tuning job. Usually, 3 epochs is a reasonable number.
#
# **Let's explore our dataset and estimate our fine-tuning costs.**

# %%
encoding
# Out:
# <Encoding 'o200k_base'>

# %%
import json
import tiktoken
import numpy as np
from typing import List, Dict, Any
from pathlib import Path

encoding = tiktoken.encoding_for_model("gpt-4o")


def num_tokens_from_messages(
    messages: List[Dict[str, Any]],
    tokens_per_message: int = 3,
    tokens_per_name: int = 1,
) -> int:
    num_tokens = tokens_per_message * len(messages) + 3
    for message in messages:
        for key, value in message.items():
            num_tokens += len(
                encoding.encode(value if isinstance(value, str) else str(value))
            )
            if key == "name":
                num_tokens += tokens_per_name
    return num_tokens


files = ["../data/stock-train.jsonl"]

for file in files:
    print(f"Processing file: {file}")
    with Path(file).open("r", encoding="utf-8") as f:
        dataset = [json.loads(line) for line in f]

    total_tokens = [num_tokens_from_messages(ex.get("messages", {})) for ex in dataset]
    test = [ex.get("messages", {}) for ex in dataset]
price = 0.08
training_cost_per_token = price / 1000
num_epochs = 3
total_cost = np.sum(total_tokens) * training_cost_per_token * num_epochs
print(f"Total cost: ${total_cost:.2f}")
# Out:
# Processing file: ../data/stock-train.jsonl
# Total cost: $1.56

# %%
test
# Out:
# [[{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What's the highest stock price that ING Group reached in the last 5 days?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "ING", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the closing price of Boeing's stock yesterday?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "BA", "period": "1d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Netflix's stock reached within the last 2 years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "NFLX", "period": "2y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Zoom's stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "ZM", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was Porsche's stock price at the beginning of this year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "POAHY", "period": "ytd"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Google's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "GOOGL"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user', 'content': 'What is the latest stock price for Airbnb?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "ABNB"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "Do you have information on Facebook's current stock price?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "FB"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Sky's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "SKY", "period": "1d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Facebook's stock yesterday?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "FB", "period": "1d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user', 'content': "What's the current stock price for Zoom?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "ZM"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the highest price that Lowe's Companies stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "LOW", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'What is the ongoing stock value for General Motors?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "GM"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the lowest price for Wells Fargo's stock last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "WFC", "period": "1w"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': 'What is the current stock price of Biogen?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "BIIB"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Google's stock reached last year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "GOOGL", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What was today's closing price for AbbVie?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "ABBV"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How has Netflix's stock been performing in the last 5 years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "NFLX", "period": "5y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': 'How much is a share in FirstEnergy Corp?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "FE"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the opening price of Dollar General's stock five days ago?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "DG", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What's the current price for a share in Lemonade?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "LMND"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "Has AT&T's stock price decreased in the past quarter?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "T", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What's the current stock price for Liberty Mutual?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "LMHC"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of BMW's stock on the market today?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "BMWYY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Vertex Pharmaceuticals's stock last Friday?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "VRTX", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Microsoft's stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "MSFT", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was FedEx's highest stock price last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "FDX", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What's the current stock price of Sanofi?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "SNY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'Could you let me know the current stock price for Shopify?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "SHOP"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What is the current value of L3Harris Technologies' stock price?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "LHX"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Boeing's stock reached this year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "BA", "period": "ytd"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the closing price of Vodafone's stock in the last 6mo?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "VOD", "period": "6mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Toyota's stock reached in the past year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "TM", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What was Gilead's stock price five days ago?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "GILD", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Comcast's stock yesterday?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "CMCSA", "period": "1d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What is the current price of ConocoPhillips's stock?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "COP"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What's the existing share price for Honda Motor Company?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "HMC"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What is Credit Suisse's current stock price?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "CS"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Home Depot's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "HD"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the highest price of Pfizerï¿½s stock in the past 6 months?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "PFE", "period": "6mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the average stock price of Digital Realty in the past six months?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "DLR", "period": "6mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Gucci's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "PPRUY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'What was the average Amgen, Inc. stock price in the past year?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "AMGN", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user', 'content': "What's Cloudflare stock's latest price?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "NET"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How has UBS Group's stock performed in the last 2 years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "UBS", "period": "2y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Allstate's stock reached last month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "ALL", "period": "1mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Nike's stock reached in the past month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "NKE", "period": "1mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What's the current stock price for Moog Inc?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "MOG.A"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price for Mastercard's stock this week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "MA", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'I am interested in the current price for each Roblox stock.'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "RBLX"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'How was the stock price for Laureate Education in the past six months?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "LAUR", "period": "6mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How much is AAR Corp.'s stock worth right now?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "AIR"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What's the current price of Celgene's stock?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "CELG"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'What was the closing price of Gilead Sciences stock on the last trading day?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "GILD"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the average stock price of Public Storage in the past quarter?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "PSA", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'What was the opening stock price for Total last Friday?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "TOT", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the average stock price of Tesla in the past 5 years?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "TSLA", "period": "5y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the stock price of General Dynamics 3 months ago?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "GD", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was AXA's opening stock price 5 years ago?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "AXA", "period": "5y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Liberty Media's stock this week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "FWONA", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What's the current price of GlaxoSmithKline's stock?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "GSK"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the lowest price that Simon Property Group's stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "SPG", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Abbott Laboratories's stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "ABT", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What's the current value of a share in Edison International?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "EIX"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Nippon Telegraph's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "NTT", "period": "1d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How much was Jazz Pharmaceuticals's stock price 3 months ago?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "JAZZ", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What's the present share price for The Allstate Corporation?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "ALL"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Slack's stock reached last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "WORK", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'Can you fetch me the current stock value of BMW?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "BMWYY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How much was Bristol-Myers Squibb's stock price 3 months ago?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "BMY", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'Could you tell me the current price per share for The Chubb Corporation?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "CB"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How has Bridgepoint Education's stock performed over the last 5 years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "BPI", "period": "5y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What's the current price of Matson, Inc.'s stock?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "MATX"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'How much is a share in Public Service Enterprise Group?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "PEG"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Comcast's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "CMCSA"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': 'How much is a share in WEC Energy Group?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "WEC"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the peak stock price of Roche in the previous year?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "RHHBY", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "How much was the closing price of PepsiCo's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "PEP"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "Has Warner Media's stock price increased over the past month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "WM", "period": "1mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the highest price that Home Depot's stock reached last month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "HD", "period": "1mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the lowest price that Hyundai's stock reached in the last three months?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "HYMTF", "period": "3mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the average stock price of Apple in the past 5 days?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "AAPL", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user', 'content': "What is the current price of Tesla's stock?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "TSLA"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Biogen's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "BIIB"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Fiat's stock reached in the last two years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "FCAU", "period": "2y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the average Coca-Cola's stock price in the past year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "KO", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was today's opening price for Bristol Myers Squibb?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "BMY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was Scripps Networks Interactive's highest stock price in the past 5 years?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "SNI", "period": "5y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was the highest price that AT&T's stock reached in the last five days?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "T", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user', 'content': "What's the current stock price for Snowflake?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "SNOW"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the opening price of Slack's stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "WORK"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price for Costco's stock last month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "COST", "period": "1mo"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price that Caterpillar's stock reached last year?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "CAT", "period": "1y"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': 'How much does a share cost currently for Capital One Financial Corporation?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "COF"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Hershey's stock yesterday?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "HSY"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the closing price of Mars Inc.'s stock this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "PRIVATE"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices.'},
#   {'role': 'user',
#    'content': "What was FirstEnergy's stock price this morning?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "FE"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the highest price for Procter & Gamble Co.'s stock last week?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "PG", "period": "5d"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': 'What was the opening stock price of LinkedIn today?'},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_current_stock_price',
#     'arguments': '{"symbol": "LNKD"}'}}],
#  [{'role': 'system',
#    'content': 'You are an assistant that provides functions related to stock prices. '},
#   {'role': 'user',
#    'content': "What was the lowest price that Apple's stock reached last month?"},
#   {'role': 'assistant',
#    'function_call': {'name': 'get_last_nday_stock_price',
#     'arguments': '{"symbol": "AAPL", "period": "1mo"}'}}]]

# %% [markdown]
# ### 3. Uploading the training and validation data to Azure OpenAI

# %%
from pathlib import Path
import os
from openai import AzureOpenAI
from dotenv import load_dotenv

load_dotenv(override=True)

azure_endpoint = os.getenv("AOAI_ENDPOINT")
aoai_api_key = os.getenv("AOAI_API_KEY")
api_version = os.getenv("AOAI_API_VERSION")

client = AzureOpenAI(
    azure_endpoint=azure_endpoint,
    api_key=aoai_api_key,
    api_version=api_version,
)

training_file_path = "../data/stock-train.jsonl"
validation_file_path = "../data/stock-test.jsonl"

# Upload the training and validation dataset files to Azure OpenAI with the SDK.
training_response = client.files.create(
    file=open(training_file_path, "rb"), purpose="fine-tune"
)
training_file_id = training_response.id

validation_response = client.files.create(
    file=open(validation_file_path, "rb"), purpose="fine-tune"
)
validation_file_id = validation_response.id

print("Training file ID:", training_file_id)
print("Validation file ID:", validation_file_id)
# Out:
# Training file ID: file-d8b3b321faf1473fb2ee24fd42cafcb9
# Validation file ID: file-eccda1b783c047afb7d444c3fc341e2f

# %% [markdown]
# ### 4. Submit your fine-tuning training job

# %%
response = client.fine_tuning.jobs.create(
    training_file=training_file_id,
    validation_file=validation_file_id,
    model="gpt-4o-mini",
    seed=123,
)

job_id = response.id

print("Job ID:", response.id)
print("Status:", response.status)
print(response.model_dump_json(indent=2))
# Out:
# Job ID: ftjob-a9d2614286ad4c4d93c4ec4bcdd14f2e
# Status: pending
# {
#   "id": "ftjob-a9d2614286ad4c4d93c4ec4bcdd14f2e",
#   "created_at": 1734459973,
#   "error": null,
#   "fine_tuned_model": null,
#   "finished_at": null,
#   "hyperparameters": {
#     "n_epochs": -1,
#     "batch_size": -1,
#     "learning_rate_multiplier": 1
#   },
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "fine_tuning.job",
#   "organization_id": null,
#   "result_files": null,
#   "seed": 123,
#   "status": "pending",
#   "trained_tokens": null,
#   "training_file": "file-d8b3b321faf1473fb2ee24fd42cafcb9",
#   "validation_file": "file-eccda1b783c047afb7d444c3fc341e2f",
#   "estimated_finish": null,
#   "integrations": null
# }

# %% [markdown]
# ### 5. Track training job status

# %% [markdown]
# You should expect to spend 60-90 min running this sample

# %%
# Track training status
from IPython.display import clear_output
import time

start_time = time.time()

# Get the status of our fine-tuning job.
response = client.fine_tuning.jobs.retrieve(job_id)

status = response.status

# If the job isn't done yet, poll it every 10 seconds.
while status not in ["succeeded", "failed"]:
    time.sleep(10)

    response = client.fine_tuning.jobs.retrieve(job_id)
    print(response.model_dump_json(indent=2))
    print(
        "Elapsed time: {} minutes {} seconds".format(
            int((time.time() - start_time) // 60), int((time.time() - start_time) % 60)
        )
    )
    status = response.status
    print(f"Status: {status}")
    clear_output(wait=True)

print(f"Fine-tuning job {job_id} finished with status: {status}")

# List all fine-tuning jobs for this resource.
print("Checking other fine-tune jobs for this resource.")
response = client.fine_tuning.jobs.list()
print(f"Found {len(response.data)} fine-tune jobs.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 14
#      12 # If the job isn't done yet, poll it every 10 seconds.
#      13 while status not in ["succeeded", "failed"]:
# ---> 14     time.sleep(10)
#      16     response = client.fine_tuning.jobs.retrieve(job_id)
#      17     print(response.model_dump_json(indent=2))
#
# KeyboardInterrupt:

# %% [markdown]
# Retrieve fine tuned model name

# %%
response = client.fine_tuning.jobs.retrieve(job_id)
print(response.model_dump_json(indent=2))
fine_tuned_model = response.fine_tuned_model
# Out:
# {
#   "id": "ftjob-c04c792f32f14e099e56862699f4baa2",
#   "created_at": 1728569830,
#   "error": null,
#   "fine_tuned_model": "gpt-4o-mini-2024-07-18.ft-c04c792f32f14e099e56862699f4baa2",
#   "finished_at": 1728572547,
#   "hyperparameters": {
#     "n_epochs": 3,
#     "batch_size": 1,
#     "learning_rate_multiplier": 1
#   },
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "fine_tuning.job",
#   "organization_id": null,
#   "result_files": [
#     "file-4d4b0b23e24545a49559777583ae57b9"
#   ],
#   "seed": 123,
#   "status": "succeeded",
#   "trained_tokens": 19662,
#   "training_file": "file-8e3c156d957f4be691b8c8b57fc1495f",
#   "validation_file": "file-619b527be838472aa01e5434e8623683",
#   "estimated_finish": null,
#   "integrations": null
# }

# %% [markdown]
# ### 6. Deploy fine-tuned model

# %% [markdown]
# You can deploy your fine-tuned model using any of the other common deployment methods like Azure OpenAI Studio. Alternatively, you can deploy your fine-tuned model using the Rest API which requires separate authorization, a different API path, and a different API version.

# %%
# Deploy fine-tuned model

import json
import requests

token = os.getenv("TEMP_AUTH_TOKEN")
subscription = os.getenv("AZ_SUBSCRIPTION_ID")
resource_group = os.getenv("AZ_RESOURCE_GROUP_NAME")
resource_name = os.getenv("AZ_AI_SERVICE_NAME")
model_deployment_name = "gpt-4o-mini-2024-07-18-ft"  ### any name you want

deploy_params = {"api-version": "2023-05-01"}
deploy_headers = {
    "Authorization": "Bearer {}".format(token),
    "Content-Type": "application/json",
}

deploy_data = {
    "sku": {"name": "standard", "capacity": 50},
    "properties": {
        "model": {
            "format": "OpenAI",
            "name": "gpt-4o-mini-2024-07-18.ft-c04c792f32f14e099e56862699f4baa2",
            "version": "1",
        }
    },
}
deploy_data = json.dumps(deploy_data)

request_url = f"https://management.azure.com/subscriptions/{subscription}/resourceGroups/{resource_group}/providers/Microsoft.CognitiveServices/accounts/{resource_name}/deployments/{model_deployment_name}"

print("Creating a new deployment...")

r = requests.put(
    request_url, params=deploy_params, headers=deploy_headers, data=deploy_data
)

print(r)
print(r.reason)
print(r.json())
# Out:
# Creating a new deployment...
# <Response [201]>
# Created
# {'id': '/subscriptions/06d043e2-5a2e-46bf-bf48-fffee525f377/resourceGroups/demofinetunning-ncus-rg/providers/Microsoft.CognitiveServices/accounts/demofinetunning-ncus-aiservice/deployments/gpt-4o-mini-2024-07-18-ft', 'type': 'Microsoft.CognitiveServices/accounts/deployments', 'name': 'gpt-4o-mini-2024-07-18-ft', 'sku': {'name': 'standard', 'capacity': 50}, 'properties': {'model': {'format': 'OpenAI', 'name': 'gpt-4o-mini-2024-07-18.ft-c04c792f32f14e099e56862699f4baa2', 'version': '1'}, 'versionUpgradeOption': 'NoAutoUpgrade', 'capabilities': {'chatCompletion': 'true', 'jsonObjectResponse': 'true', 'maxContextToken': '128000', 'maxOutputToken': '16384', 'assistants': 'true'}, 'provisioningState': 'Creating'}, 'systemData': {'createdBy': 'pablocastao@microsoft.com', 'createdByType': 'User', 'createdAt': '2024-10-10T16:01:22.7802221Z', 'lastModifiedBy': 'pablocastao@microsoft.com', 'lastModifiedByType': 'User', 'lastModifiedAt': '2024-10-10T16:01:22.7802221Z'}, 'etag': '"9addfdcd-18b5-4811-bdd1-eb8c45cb8310"'}

# %%
# Azure Management API URL
url = f"https://management.azure.com/subscriptions/{subscription}/resourceGroups/{resource_group}/providers/Microsoft.CognitiveServices/accounts?api-version=2021-04-30"

# Replace 'your_access_token' with your actual Azure AD token
headers = {
    "Authorization": "Bearer {}".format(token),
    "Content-Type": "application/json",
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    resources = response.json()
    print(json.dumps(resources, indent=4))
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {
#     "value": [
#         {
#             "id": "/subscriptions/06d043e2-5a2e-46bf-bf48-fffee525f377/resourceGroups/demofinetunning-ncus-rg/providers/Microsoft.CognitiveServices/accounts/demofinetunning-ncus-aiservice",
#             "name": "demofinetunning-ncus-aiservice",
#             "type": "Microsoft.CognitiveServices/accounts",
#             "etag": "\"04009e3f-0000-0400-0000-6707df1a0000\"",
#             "location": "northcentralus",
#             "sku": {
#                 "name": "S0"
#             },
#             "kind": "AIServices",
#             "properties": {
#                 "endpoint": "https://northcentralus.api.cognitive.microsoft.com/",
#                 "internalId": "ee4b4bda587c4ce8a8b53cc2ce20b7b2",
#                 "dateCreated": "2024-10-10T14:04:38.5080292Z",
#                 "callRateLimit": {
#                     "rules": [
#                         {
#                             "key": "documentTranslation.post",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/text/batch/*",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "documentTranslation.get",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/text/batch/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "documentTranslation.default",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/text/batch/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textTranslation",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/text/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "singledocumentTranslation.default",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/document:translate",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "batchDocumentTranslation.default",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "translator/document/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "workflow.endpoint.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/:analyze-conversations",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.conversations.jobs.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/jobs/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.conversations.jobs.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/jobs",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyzetext.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/:analyze-text",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyzetext.jobs.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/jobs/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyzetext.jobs.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 300,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/jobs",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyzedocuments.jobs.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-documents/jobs/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyzedocuments.jobs.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-documents/jobs",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.generate.postcalls",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/:generate",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.authoring.customtext.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.updatecalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.authoring.customtext.march.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/authoring/analyze-text/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.march.updatecalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/authoring/analyze-text/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.authoring.customtext.internal.getcalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/internal/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.internal.updatecalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-text/internal/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.getCalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.updateCalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.march.getCalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/authoring/analyze-conversations/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.march.updateCalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/authoring/analyze-conversations/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.internal.getCalls",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/internal/projects/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.unifiedAuthoring.clu.internal.updateCalls",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/analyze-conversations/internal/projects/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.customText",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "text/analytics/v3.1-preview.ct.1/analyze/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyze",
#                             "renewalPeriod": 60,
#                             "count": 300,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "text/analytics/v3.1/analyze/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "text/analytics/v3.2-preview.1/analyze/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "text/analytics/v3.2-preview.2/analyze/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.healthcare",
#                             "renewalPeriod": 60,
#                             "count": 300,
#                             "matchPatterns": [
#                                 {
#                                     "path": "text/analytics/v3.1/entities/health",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "text/analytics/v3.2-preview.1/health",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "text/analytics/v3.2-preview.2/health",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.languagedetection",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "matchPatterns": [
#                                 {
#                                     "path": "text/analytics/v3.1/languages",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics",
#                             "renewalPeriod": 60,
#                             "count": 1000,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "text/analytics/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "questionanswering",
#                             "renewalPeriod": 60,
#                             "count": 600,
#                             "matchPatterns": [
#                                 {
#                                     "path": "qnamaker/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "unifiedlanguage.questionanswering",
#                             "renewalPeriod": 1,
#                             "count": 3,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/query-knowledgebases/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "unifiedlanguage.questionanswering.inference",
#                             "renewalPeriod": 1,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "language/:query-*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyze.internal.autoTagging",
#                             "renewalPeriod": 60,
#                             "count": 150,
#                             "matchPatterns": [
#                                 {
#                                     "path": "TextAnalytics/ct-auto-tagging",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "textAnalytics.analyze.internal.evaluation",
#                             "renewalPeriod": 60,
#                             "count": 150,
#                             "matchPatterns": [
#                                 {
#                                     "path": "TextAnalytics/ct-evaluation",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "token",
#                             "renewalPeriod": 1,
#                             "count": 50,
#                             "matchPatterns": [
#                                 {
#                                     "path": "sts/v1.0/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.synthesize",
#                             "renewalPeriod": 1,
#                             "count": 200,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/synthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.customvoicesynthesize",
#                             "renewalPeriod": 1,
#                             "count": 200,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/customvoicesynthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.neuralvoicesynthesize",
#                             "renewalPeriod": 1,
#                             "count": 200,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/neuralvoicesynthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.aoaivoicesynthesize",
#                             "renewalPeriod": 60,
#                             "count": 10,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/aoaivoicesynthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.aoaihdvoicesynthesize",
#                             "renewalPeriod": 60,
#                             "count": 3,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/aoaihdvoicesynthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.customneuralvoicesynthesize",
#                             "renewalPeriod": 1,
#                             "count": 200,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/customneuralvoicesynthesize",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.liveavatarconnect",
#                             "renewalPeriod": 60,
#                             "count": 1,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/liveavatarconnect",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.livecustomavatarconnect",
#                             "renewalPeriod": 60,
#                             "count": 1,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/livecustomavatarconnect",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.batchavatarcreate",
#                             "renewalPeriod": 60,
#                             "count": 2,
#                             "matchPatterns": [
#                                 {
#                                     "path": "avatar/batchsyntheses/*",
#                                     "method": "PUT"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.conversationtranscription",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speech/singlechannelaudioconversationtranscription",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "speech/multichannelaudioconversationtranscribe",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "speech/videoconversationtranscribe",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.speechtotext",
#                             "renewalPeriod": 10,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speechtotext/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.batchtexttospeechcreate",
#                             "renewalPeriod": 10,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "texttospeech/batchsyntheses/*",
#                                     "method": "PUT"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.texttospeech",
#                             "renewalPeriod": 10,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "texttospeech/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.customvoice",
#                             "renewalPeriod": 10,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "customvoice/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.speakerrecognitionv2",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "speaker/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "speaker-recognition/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "speech.speakerrecognitionv1",
#                             "renewalPeriod": 1,
#                             "count": 5,
#                             "matchPatterns": [
#                                 {
#                                     "path": "spid/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.analyze",
#                             "renewalPeriod": 1,
#                             "count": 15,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "formrecognizer/custom/models/{id}/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/businessCard/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/idDocument/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/invoice/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/layout/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/receipt/analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/receipt/asyncBatchAnalyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels/{modelId}:analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/read",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers/{classifierId}:analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels/{modelId}:analyze",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers/{classifierId}:analyze",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.get.object",
#                             "renewalPeriod": 1,
#                             "count": 50,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/businessCard/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/idDocument/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/invoice/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/receipt/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/prebuilt/receipt/operations/{operationId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels/{modelId}/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/layout/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}/copyResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/operations/{operationId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{id}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels/{modelId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers/{classifierId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers/{classifierId}/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels/{modelId}/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/operations/{operationId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels/{modelId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers/{classifierId}",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers/{classifierId}/analyzeResults/{resultId}",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.list.objects",
#                             "renewalPeriod": 1,
#                             "count": 10,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "formrecognizer/operations",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/info",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/operations",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/info",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.model.management",
#                             "renewalPeriod": 1,
#                             "count": 5,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "formrecognizer/custom/models",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/compose",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/copyAuthorization",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{id}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{id}/keys",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}/copy",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels/{modelId}:copyTo",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels:authorizeCopy",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels:build",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels:compose",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/train",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/custom/models/{modelId}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentModels/{modelId}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers:build",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "formrecognizer/documentClassifiers/{classifierId}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels:authorizeCopy",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels/{modelId}:copyTo",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels:build",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels:compose",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentModels/{modelId}",
#                                     "method": "DELETE"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers:build",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "documentintelligence/documentClassifiers/{classifierId}",
#                                     "method": "DELETE"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.chat.build",
#                             "renewalPeriod": 1,
#                             "count": 15,
#                             "matchPatterns": [
#                                 {
#                                     "path": "documentintelligence/chat:build",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "formrecognizer.chat.complete",
#                             "renewalPeriod": 60,
#                             "count": 5,
#                             "matchPatterns": [
#                                 {
#                                     "path": "documentintelligence/chat/{chatId}:complete",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "vision.recognizeText",
#                             "renewalPeriod": 1,
#                             "count": 30,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "vision/recognizeText",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "vision/textOperations/*",
#                                     "method": "GET"
#                                 },
#                                 {
#                                     "path": "vision/read/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "vision",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "vision/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "container.billing",
#                             "renewalPeriod": 10,
#                             "count": 500,
#                             "matchPatterns": [
#                                 {
#                                     "path": "billing/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.List",
#                             "renewalPeriod": 1,
#                             "count": 10,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/text/blocklists*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.TextGroundedDetection",
#                             "renewalPeriod": 1,
#                             "count": 50,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
# ...
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/image:detectIncidents*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.ImageIncidentResponse",
#                             "renewalPeriod": 10,
#                             "count": 100,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/image/incidents*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.Image",
#                             "renewalPeriod": 10,
#                             "count": 1000,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/image*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.Project",
#                             "renewalPeriod": 1,
#                             "count": 30,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/projects*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.Metrics",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/metrics*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafety.Feature",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/whitelist*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafetyInternal.Metrics",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/internal/metrics*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "ContentSafetyInternal.Feature",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "dynamicThrottlingEnabled": true,
#                             "matchPatterns": [
#                                 {
#                                     "path": "contentsafety/internal/whitelist*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.dalle.post",
#                             "renewalPeriod": 1,
#                             "count": 30,
#                             "matchPatterns": [
#                                 {
#                                     "path": "dalle/*",
#                                     "method": "POST"
#                                 },
#                                 {
#                                     "path": "openai/images/*",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.dalle.other",
#                             "renewalPeriod": 1,
#                             "count": 30,
#                             "matchPatterns": [
#                                 {
#                                     "path": "dalle/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "openai/operations/images/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.assistants.default",
#                             "renewalPeriod": 1,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "openai/assistants/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "openai/threads/*",
#                                     "method": "*"
#                                 },
#                                 {
#                                     "path": "openai/vector_stores/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.batches.post",
#                             "renewalPeriod": 60,
#                             "count": 30,
#                             "matchPatterns": [
#                                 {
#                                     "path": "openai/batches/*",
#                                     "method": "POST"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.batches.get",
#                             "renewalPeriod": 60,
#                             "count": 500,
#                             "matchPatterns": [
#                                 {
#                                     "path": "openai/batches/*",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai.batches.list",
#                             "renewalPeriod": 60,
#                             "count": 100,
#                             "matchPatterns": [
#                                 {
#                                     "path": "openai/batches",
#                                     "method": "GET"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "openai",
#                             "renewalPeriod": 1,
#                             "count": 30,
#                             "matchPatterns": [
#                                 {
#                                     "path": "openai/*",
#                                     "method": "*"
#                                 }
#                             ]
#                         },
#                         {
#                             "key": "default",
#                             "renewalPeriod": 1,
#                             "count": 20,
#                             "matchPatterns": [
#                                 {
#                                     "path": "*",
#                                     "method": "*"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 "isMigrated": false,
#                 "customSubDomainName": "demoaiservicse5755697264",
#                 "privateEndpointConnections": [],
#                 "publicNetworkAccess": "Enabled",
#                 "capabilities": [
#                     {
#                         "name": "VirtualNetworks"
#                     },
#                     {
#                         "name": "TrustedServices",
#                         "value": "Microsoft.CognitiveServices,Microsoft.MachineLearningServices,Microsoft.Search"
#                     },
#                     {
#                         "name": "CustomerManagedKey"
#                     },
#                     {
#                         "name": "Container",
#                         "value": "ContentSafety.*,ContentSafety.TextAnalyze,ContentSafety.ImageAnalyze,ComputerVision.*,ComputerVision.VideoAnalytics,ComputerVision.ComputerVisionRead,ComputerVision.ocr,ComputerVision.readfile,ComputerVision.readfiledsd,ComputerVision.recognizetext,ComputerVision.ComputerVision,ComputerVision.ocrlayoutworker,ComputerVision.ocrcontroller,ComputerVision.ocrdispatcher,ComputerVision.ocrbillingprocessor,ComputerVision.ocranalyzer,ComputerVision.ocrpagesplitter,ComputerVision.ocrapi,ComputerVision.ocrengineworker,FormRecognizer.*,FormRecognizer.Forms,FormRecognizer.FormRecognizerCustomSupervised,FormRecognizer.FormRecognizerLayout,FormRecognizer.formrecognizerreadlayout,FormRecognizer.FormRecognizerId,FormRecognizer.FormRecognizerInvoice,FormRecognizer.FormRecognizerReceipt,FormRecognizer.FormRecognizerBusinessCard,FormRecognizer.FormRecognizerRead,FormRecognizer.FormRecognizerKvp,SpeechServices.*,SpeechServices.CustomSpeechToText,SpeechServices.NeuralTextToSpeechOnPrem,SpeechServices.DPP,SpeechServices.SpeechToText,SpeechServices.ctsdiarizer,SpeechServices.diarization,TextAnalytics.*,TextAnalytics.Healthcare,TextAnalytics.EntityV3,TextAnalytics.EntityONNX,TextAnalytics.Keyphrase,TextAnalytics.KeyphraseV2,TextAnalytics.KeyPhraseONNX,TextAnalytics.LanguageFastText,TextAnalytics.Language,TextAnalytics.LanguageV2,TextAnalytics.Sentiment,TextAnalytics.SentimentV2,TextAnalytics.SentimentV3,TextAnalytics.SentimentV3Preview,TextAnalytics.SentimentONNX,TextAnalytics.CustomNER,TextAnalytics.textanalyticsdispatcher,TextAnalytics.SummarizationFrontend,TextAnalytics.SummarizationWorker,TextAnalytics.PII,TextTranslation.*"
#                     },
#                     {
#                         "name": "Cloud",
#                         "value": "TextAnalytics.Healthcare,TextAnalytics.Analyze,QuestionAnswer.AllApis,LanguageService.QuestionAnsweringApis"
#                     }
#                 ],
#                 "endpoints": {
#                     "OpenAI Language Model Instance API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "OpenAI Dall-E API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "OpenAI Whisper API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "OpenAI Model Scaleset API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "OpenAI Realtime API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "Token Service API": "https://demoaiservicse5755697264.openai.azure.com/",
#                     "Content Safety": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Container": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Computer Vision": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "FormRecognizer": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speech to Text": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speech to Text v3.2": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speech to Text 2024-05-15-preview": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speech to Text v3.2_internal.1": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Custom Voice": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Video Translation": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Audio Content Creation": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Custom Avatar": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Batch Avatar": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Batch Text to Speech": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speech to Text (Standard)": "https://swedencentral.stt.speech.microsoft.com",
#                     "Speech Services Text to Speech (Neural)": "https://swedencentral.tts.speech.microsoft.com",
#                     "Speech Services Speaker Verification": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Speech Services Speaker Identification": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Token": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Text Analytics": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Custom Text Authoring": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Conversational Language Understanding Authoring": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Custom Question Answering Authoring": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Custom Question Answering": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "ConversationalLURuntime": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Language": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "QnAMaker": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "Turing": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "QuestionAnswering": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "LUIS": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "TextTranslation-Global": "https://api.cognitive.microsofttranslator.com/",
#                     "TextTranslation": "https://demoaiservicse5755697264.cognitiveservices.azure.com/",
#                     "DocumentTranslation": "https://demoaiservicse5755697264.cognitiveservices.azure.com/"
#                 },
#                 "provisioningState": "Succeeded"
#             },
#             "systemData": {
#                 "createdBy": "pablocastao@microsoft.com",
#                 "createdByType": "User",
#                 "createdAt": "2024-10-10T14:11:37.374248Z",
#                 "lastModifiedBy": "pablocastao@microsoft.com",
#                 "lastModifiedByType": "User",
#                 "lastModifiedAt": "2024-10-10T14:11:37.374248Z"
#             }
#         }
#     ]
# }
